# %%
import pandas as pd

# %%
df=pd.read_csv(r"D:\DOT SLASH\features2.csv")

# %%
df
# Out:
#       Unnamed: 0                 date  1. open  2. high   3. low  4. close  \
# 0              0  2025-01-02 04:00:00  22.7100  22.9000  22.7100   22.9000
# 1              1  2025-01-02 04:01:00  22.7900  22.7900  22.7800   22.7800
# 2              2  2025-01-02 04:02:00  22.7900  22.8400  22.7900   22.8400
# 3              3  2025-01-02 04:03:00  22.8100  22.8100  22.8100   22.8100
# 4              4  2025-01-02 04:05:00  22.8400  22.8400  22.8300   22.8300
# ...          ...                  ...      ...      ...      ...       ...
# 8814        8814  2025-01-31 18:36:00  21.9010  21.9010  21.9010   21.9010
# 8815        8815  2025-01-31 18:59:00  21.9895  21.9895  21.9895   21.9895
# 8816        8816  2025-01-31 19:00:00  21.9500  21.9500  21.9500   21.9500
# 8817        8817  2025-01-31 19:39:00  21.9896  21.9896  21.9896   21.9896
# 8818        8818  2025-01-31 19:53:00  21.9300  21.9300  21.9300   21.9300
#
# ...

# %%
df.drop(['Unnamed: 0','Comprehensive_RRR','%Change','RRR','Target'], axis=1, inplace=True)

# %%
df
# Out:
#                      date  1. open  2. high   3. low  4. close  5. volume  \
# 0     2025-01-02 04:00:00  22.7100  22.9000  22.7100   22.9000      944.0
# 1     2025-01-02 04:01:00  22.7900  22.7900  22.7800   22.7800      120.0
# 2     2025-01-02 04:02:00  22.7900  22.8400  22.7900   22.8400       73.0
# 3     2025-01-02 04:03:00  22.8100  22.8100  22.8100   22.8100        3.0
# 4     2025-01-02 04:05:00  22.8400  22.8400  22.8300   22.8300      392.0
# ...                   ...      ...      ...      ...       ...        ...
# 8814  2025-01-31 18:36:00  21.9010  21.9010  21.9010   21.9010        5.0
# 8815  2025-01-31 18:59:00  21.9895  21.9895  21.9895   21.9895        1.0
# 8816  2025-01-31 19:00:00  21.9500  21.9500  21.9500   21.9500   714027.0
# 8817  2025-01-31 19:39:00  21.9896  21.9896  21.9896   21.9896        2.0
# 8818  2025-01-31 19:53:00  21.9300  21.9300  21.9300   21.9300      100.0
#
#             EMA        RSI          %K          %D        +DI        -DI  \
# ...

# %%
df.to_csv('testing_features.csv')
